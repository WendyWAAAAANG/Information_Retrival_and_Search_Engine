# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import random

def infWeb(in_page1,in_page2):
    header = {
    'Cookie': 'Hm_lvt_3dbef4cdd12921cb979bbf3f1907f2e7=1638680614; Hm_lpvt_3dbef4cdd12921cb979bbf3f1907f2e7=1638680614; Hm_lvt_9dde1144554e792a1aa49eb21640e189=1638680614; Hm_lpvt_9dde1144554e792a1aa49eb21640e189=1638680614',
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
    }
    i = 1
    d_id = []
    name = []
    price = []
    effect = []
    usage = []
    picture = []
    number = []
    for page in range(in_page1,in_page2):#20500
        requests.adapters.DEFAULT_RETRIES = 5
        s = requests.session()
        s.keep_alive = False
        url = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=0&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='+str(page)
        r = requests.get(url,headers = header)
        html_soup = BeautifulSoup(r.text, "html.parser")
        for row in html_soup.find_all('dl'):
            b_list = row.find_all('b')
            for b in b_list:
                name.append(b.find('a').text.strip())
                span_list = b.find_all('span')
                for s in span_list:
                    price.append(s.find('em').text.strip())
                    break
                break
            p = row.find_all('p')
            effect.append(p[0].text.strip())
            usage.append(p[1].text.strip())
            picture.append(row.find('img').get('src'))
    result = pd.DataFrame({'name':name, 'price':price,'effect':effect,'usage':usage,'picture':picture}).drop_duplicates()
    result.dropna(axis=0,inplace=True)
    
    random.seed()
    while (i <= result.shape[0]):
        d_id.append(str(i))
        number.append(random.randint(0,500))
        i += 1
    result.insert(0,'id',d_id)
    result.insert(6,'number',number)
    return result

da1 = infWeb(1,2000)
da2 = infWeb(2000,4000)
da3 = infWeb(4000,5000)
da4 = infWeb(6000,8000)
da5 = infWeb(8000,10000)
da6 = infWeb(10000,12000)
da7 = infWeb(12000,14000)
da8 = infWeb(14000,15000)
da9 = infWeb(16000,18000)
da10 = infWeb(18000,20000)
da11 = infWeb(20000,20500)
da_list = [da1,da2,da3,da4,da5,da6,da7,da8,da9,da10,da11]
re2 = pd.concat(da_list)

from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

def creatDataframe(in_url,in_page,in_type):
    header = {
    'Cookie': 'Hm_lvt_3dbef4cdd12921cb979bbf3f1907f2e7=1638680614; Hm_lpvt_3dbef4cdd12921cb979bbf3f1907f2e7=1638680614; Hm_lvt_9dde1144554e792a1aa49eb21640e189=1638680614; Hm_lpvt_9dde1144554e792a1aa49eb21640e189=1638680614',
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
    }
    name = []
    price = []
    effect = []
    usage = []
    picture = []
    for page in range(1,in_page):
        requests.adapters.DEFAULT_RETRIES = 5
        s = requests.session()
        s.keep_alive = False
        url = in_url+str(page)
        r = requests.get(url,headers = header)
        html_soup = BeautifulSoup(r.text, "html.parser")
        for row in html_soup.find_all('dl'):
            b_list = row.find_all('b')
            for b in b_list:
                name.append(b.find('a').text.strip())
                span_list = b.find_all('span')
                for s in span_list:
                    price.append(s.find('em').text.strip())
                    break
                break
            p = row.find_all('p')
            effect.append(p[0].text.strip())
            usage.append(p[1].text.strip())
            picture.append(row.find('img').get('src'))
    result = pd.DataFrame({'name':name, 'price':price,'effect':effect,'usage':usage,'picture':picture,'type':in_type})
    return result

url1 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4084&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page1 = 1072
type1 = '家庭常备'
url2 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=190&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page2 = 480
type2 = '皮肤用药'
url3 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4082&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page3 = 683
type3 = '肠胃用药'
url4 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=171&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page4 = 1296
type4 = '呼吸系统类'
url5 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4083&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page5 = 375
type5 = '五官用药'
url6 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4163&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page6 = 113
type6 = '男性用药'
url7 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4086&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page7 = 362
type7 = '妇科用药'
url8 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4115&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page8 = 109
type8 = '儿科用药'
url9 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=183&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page9 = 636
type9 = '维生素及营养类'

result1 = creatDataframe(url1,page1,type1)
result2 = creatDataframe(url2,page2,type2)
result3 = creatDataframe(url3,page3,type3)
result4 = creatDataframe(url4,page4,type4)
result5 = creatDataframe(url5,page5,type5)
result6 = creatDataframe(url6,page6,type6)
result7 = creatDataframe(url7,page7,type7)
result8 = creatDataframe(url8,page8,type8)
result9 = creatDataframe(url9,page9,type9)

s_list = [result1,result2,result3,result4,result5,result6,result7,result8,result9]
result = pd.concat(s_list)
result

#Data preprocessing_ Processing missing values
print(result.isnull().sum())
result.dropna(axis=0,inplace=True)

#Data preprocessing_ Processing data redundancy
drug_result = result.drop_duplicates()


import random

d_id = []
sale = []
number = []
i = 1
random.seed()
while (i <= drug_result.shape[0]):
    d_id.append(str(i))
    sale.append(random.randint(1,100))
    number.append(random.randint(0,500))
    i += 1
drug_result.insert(0,'id',d_id)
drug_result.insert(7,'sale',sale)
drug_result.insert(8,'number',number)
len(drug_result)

drug_result.to_csv('drug.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 52
#      49     result.insert(6,'number',number)
#      50     return result
# ---> 52 da1 = infWeb(1,2000)
#      53 da2 = infWeb(2000,4000)
#      54 da3 = infWeb(4000,5000)
#
# Cell In[1], line 25, in infWeb(in_page1, in_page2)
#      23 s.keep_alive = False
#      24 url = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=0&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='+str(page)
# ---> 25 r = requests.get(url,headers = header)
#      26 html_soup = BeautifulSoup(r.text, "html.parser")
#      27 for row in html_soup.find_all('dl'):
#
# File /usr/local/lib/python3.8/dist-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
# ...

# %%
url10 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=185&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page10 = 628
type10 = '心脑血管类'
url11 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=170&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page11 = 266
type11 = '肝胆胰用药'
url12 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4123&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page12 = 160
type12 = '肾病'
url13 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4087&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page13 = 204
type13 = '内分泌失常'
url14 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4089&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page14 = 353
type14 = '神经/精神'
url15 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4090&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page15 = 92
type15 = '肿瘤科'
url16 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4091&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page16 = 172
type16 = '风湿免疫科'
url17 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=172&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page17 = 98
type17 = '抗寄生虫类'
url18 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=175&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page18 = 131
type18 = '抗结核及麻风类'
url19 = 'https://ypk.99.com.cn/Home/GetDrugListByFind?classid=4092&brandid=0&drugtype=&fourtype=1&isotc=0&isyibao=0&pageindex='
page19 = 133
type19 = '性病用药'

result10 = creatDataframe(url10,page10,type10)
result11 = creatDataframe(url11,page11,type11)
result12 = creatDataframe(url12,page12,type12)
result13 = creatDataframe(url13,page13,type13)
result14 = creatDataframe(url14,page14,type14)
result15 = creatDataframe(url15,page15,type15)
result16 = creatDataframe(url16,page16,type16)
result17 = creatDataframe(url17,page17,type17)
result18 = creatDataframe(url18,page18,type18)
result19 = creatDataframe(url19,page19,type19)

s_list = [result10,result11,result12,result13,result14,result15,result16,result17,result18,result19]

result = pd.concat(s_list)
result

#Data preprocessing_ Processing missing values
print(result.isnull().sum())
result.dropna(axis=0,inplace=True)

#Data preprocessing_ Processing data redundancy
drug_result = result.drop_duplicates()

d_id = []
sale = []
number = []
i = 1
random.seed()
while (i <= drug_result.shape[0]):
    d_id.append(str(i))
    sale.append(random.randint(1,100))
    number.append(random.randint(0,500))
    i += 1
drug_result.insert(0,'id',d_id)
drug_result.insert(7,'sale',sale)
drug_result.insert(8,'number',number)
len(drug_result)

drug_result.to_json('drug.json')

# %%
# drug_result.to_csv('drug.csv')

# %%
idx = len(drug_result)//2
df1 = drug_result.iloc[0:idx]
df2 = drug_result.iloc[idx:]

# %%
df1.to_csv('drug1.csv')
df2.to_json('drug1.json')
